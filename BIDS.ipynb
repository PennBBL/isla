# %% [markdown]
# # Making sure your data is BIDS-compliant on Flywheel
#
# BIDS compliance is absolutely necessary for running many pre-processing pipelines on your data. Having correct metadata ensures that the pre-processing correctly handles your data. Incorrect BIDS naming can result in difficult-to-debug errors.
#
# For these reasons, we cover in-depth how to make sure your data is BIDS-compliant.
#
# First, let's look at an example subject.
#
# <img src="images/initial_bids_error.png" alt="drawing" width="600"/>
#
# These red flags mean that there are errors converting the images to a BIDS-compliant name. Here you have two options
#
#   1. Click the "Info" button on the scan and make sure the BIDS section is completed correctly
#   2. Use the Flywheel API to change the BIDS properties
#
#
# ## The Flywheel data model
#
# Flywheel stores zip archives of the dicom data and nifti files. The names of the nifti files are usually determined by `dcm2niix` and that name sticks with the file for the rest of its life. I believe these files are managed using MongoDB's GridFS framework, so there are some non-intuitive things that can happen.
#
#   - More than one file can exist with the exact same name. The files are indexed by a BSON id, which is
#     unique for each file. The field containing the file name is not necessarily unique.
#
#   - Unless the data was uploaded in BIDS format, the actual BIDS-named data does not exist in Flywheel.
#     Instead, when a job needs requires BIDS input, the job uses the Flywheel API to download and rename
#     the data to be BIDS compliant.
#
#     - The renaming and JSON Sidecar creation uses information stored in Flywheel's MongoDB. Therefore to
#       change the BIDS filename, you simply update the files Document/BSON and next time a gear is run,
#       this new metadata will be used to create the BIDS directory.
#
# The metadata associated with each file can be edited through the Flywheel web interface or through the API. The web interface is not complete and still a little buggy (i.e. not all UI's contain BIDS fields). The SDK is fairly complete and documented, so that will be the focus of this notebook.
#
#
# ## Editing BIDS info from the web interface
#
# You can change the information on your scans by clicking the info icon in the file's row.
#
# <img src="images/select_info.png" alt="drawing" width="600"/>
#
#
# The fields can then be edited manually. This is the initial interface presented:
#
# <img src="images/basic_file_info.png" alt="drawing" width="600"/>
#
# where basic options about the contents of the file are editable. This will always be available when clicking the Info button. If the `BIDS Curation` gear has been run, you can scroll down and see the BIDS fields:
#
# <img src="images/bids_info.png" alt="drawing" width="600"/>
#
# It is unclear to me if the `BIDS Curation` gear needs to be re-run for these changes to be committed to MongoDB.
#
# ## Editing BIDS info from the API
#
# The Flywheel SDK can be installed from PyPI using
#
# ```bash
#
# pip install flywheel-sdk
#
# ```
#
# The documentation for this package can be found [here](https://flywheel-io.github.io/core/branches/master/python/index.html).

# %%
import flywheel

# Create client
fw = flywheel.Client()

# %% [markdown]
# ## Logging In to Flywheel
#
# Note the documentation is out of date and the constructor for `flywheel.Client` does not take any arguments. Instead you have to login with your API key using the commandline `fw login`. Verify that your login worked and you can retrieve data from Flywheel:

# %%
fw.get_current_user()['email']
# Out:
# 'tinashemtapera@gmail.com'

# %% [markdown]
# ## The Basic Data Model
#
# Everything in flywheel is a *container*. >>>
#
# <img src="images/data-model.png" alt="drawing" width="600"/>
#
# When you access a container, you can either do so as a method attribute, or a function. With a method, you implement a flywheel finder which indexes the data but doesn't quite return anything to you yet. As a function, the returned object usually is a dictionary (or list of dictionaries).
#
# For example, we can see the currently available project containers with the following command:

# %%
# the function
fw.projects()
# Out:
# [{'analyses': None,
#   'created': datetime.datetime(2018, 12, 13, 18, 23, 41, 986000, tzinfo=tzutc()),
#   'description': None,
#   'files': [],
#   'group': 'mcieslak',
#   'id': '5c12a3ad9011bd0013368726',
#   'info': {},
#   'info_exists': False,
#   'label': 'BBLTest',
#   'modified': datetime.datetime(2019, 2, 7, 17, 39, 35, 998000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': None,
#               'session': None,
#               'subject': None},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'tags': [],
#   'template': None}, {'analyses': None,
#   'created': datetime.datetime(2018, 12, 19, 15, 21, 10, 217000, tzinfo=tzutc()),
#   'description': None,
#   'files': [{'classification': {},
#              'created': datetime.datetime(2019, 1, 9, 19, 48, 52, 13000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-1c77469675dad45012de0cbf1da5053e27918713ad822de64502a711d0238e56bc7b3f94946ba1e8d1921d1c8d68d1d4',
#              'id': '66463c4e-c46b-4975-868d-fb48c45039e8',
#              'info': {u'BIDS': {u'Filename': u'',
#                                 u'Folder': u'',
#                                 u'Path': u'',
#                                 u'error_message': u"Filename u'' is too short",
#                                 u'ignore': False,
#                                 u'template': u'project_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'text/plain',
#              'modality': None,
#              'modified': datetime.datetime(2019, 1, 9, 22, 38, 19, 579000, tzinfo=tzutc()),
#              'name': 'freesurferlicese.txt',
#              'origin': {'id': 'azeez.adebimpe5@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 62,
#              'tags': [],
#              'type': 'text',
#              'zip_member_count': None}],
#   'group': 'mcieslak',
#   'id': '5c1a61e69011bd0011368884',
#   'info': {u'BIDS': {u'Acknowledgements': u'',
#                      u'Authors': [],
#                      u'BIDSVersion': u'1.0.2',
#                      u'DatasetDOI': u'',
#                      u'Funding': u'',
#                      u'HowToAcknowledge': u'',
#                      u'License': u'',
#                      u'Name': u'Reward2018',
#                      u'ReferencesAndLinks': [],
#                      u'template': u'project'}},
#   'info_exists': True,
#   'label': 'Reward2018',
#   'modified': datetime.datetime(2019, 2, 12, 16, 8, 59, 700000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': None,
#               'session': None,
#               'subject': None},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'tags': [],
#   'template': None}]

# %%
# the indexer
fw.projects

# %% [markdown]
# ## Searching the Data
#
# The indexer itself has some common search methods such as `find()` and `find_first()`.

# %%
project = fw.projects.find_first('label=Reward2018')
print(project)
# Out:
# {'analyses': None,
#  'created': datetime.datetime(2018, 12, 19, 15, 21, 10, 217000, tzinfo=tzutc()),
#  'description': None,
#  'files': [{'classification': {},
#             'created': datetime.datetime(2019, 1, 9, 19, 48, 52, 13000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-1c77469675dad45012de0cbf1da5053e27918713ad822de64502a711d0238e56bc7b3f94946ba1e8d1921d1c8d68d1d4',
#             'id': '66463c4e-c46b-4975-868d-fb48c45039e8',
#             'info': {u'BIDS': {u'Filename': u'',
#                                u'Folder': u'',
#                                u'Path': u'',
#                                u'error_message': u"Filename u'' is too short",
#                                u'ignore': False,
#                                u'template': u'project_file',
#                                u'valid': False}},
#             'info_exists': True,
#             'mimetype': 'text/plain',
#             'modality': None,
#             'modified': datetime.datetime(2019, 1, 9, 22, 38, 19, 579000, tzinfo=tzutc()),
#             'name': 'freesurferlicese.txt',
#             'origin': {'id': 'azeez.adebimpe5@gmail.com',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 62,
#             'tags': [],
#             'type': 'text',
#             'zip_member_count': None}],
#  'group': 'mcieslak',
#  'id': '5c1a61e69011bd0011368884',
#  'info': {u'BIDS': {u'Acknowledgements': u'',
#                     u'Authors': [],
#                     u'BIDSVersion': u'1.0.2',
#                     u'DatasetDOI': u'',
#                     u'Funding': u'',
#                     u'HowToAcknowledge': u'',
#                     u'License': u'',
#                     u'Name': u'Reward2018',
#                     u'ReferencesAndLinks': [],
#                     u'template': u'project'}},
#  'info_exists': True,
#  'label': 'Reward2018',
#  'modified': datetime.datetime(2019, 2, 12, 16, 8, 59, 700000, tzinfo=tzutc()),
#  'notes': [],
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'mcieslak',
#              'project': None,
#              'session': None,
#              'subject': None},
#  'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#  'public': None,
#  'tags': [],
#  'template': None}

# %% [markdown]
# Once you can find a container by label, use the BSON id to extract its other key-value pairs. You'll notice that there is an `'_id'` field in all of these documents. This is the BSON id that is used to identify files in flywheel. Everything - files, subjects, sessions, analyses - has one of these that can be used for direct access. Confusingly, you can't access it directly with `project['id']`: you'll need to use `project['_id']`.

# %%
project['_id']
# Out:
# '5c1a61e69011bd0011368884'

# %% [markdown]
# In MongoDB, containers don't have to be accessed in order. For example, we can pull the subjects out of the project here:

# %%
for subject in project.subjects():
        print('%s: %s' % (subject.id, subject.label))
# Out:
# 5c352b991de80b0024480dda: 10180
# 5c352a081de80b0024480dcc: 102102
# 5c3535641de80b0024480e41: 104059
# 5c3527fe1de80b0024480db7: 10410
# 5c3541301de80b0024480ebc: 105168
# 5c353ab01de80b00198acafb: 105272
# 5c3542de1de80b00198acb34: 105490
# 5c35186f1de80b00198ac9f9: 105634
# 5c3539ea1de80b001c0da9c8: 106573
# 5c353e151de80b0024480ea0: 107055
# 5c3545391de80b00198acb42: 109741
# 5c3511cd1de80b0024480c9f: 11010
# 5c3532511de80b0024480e26: 11176
# 5c351c2f1de80b00156d3d76: 11186
# 5c1a8b619011bd0011369953: 11242
# 5c1a8b249011bd001436aa02: 11305
# 5c1a8acd9011bd0015369b48: 113220
# 5c1a89509011bd001436a68d: 11399
# 5c1a7e469011bd00153689f7: 19446
# 5c1a88ff9011bd0013369d0d: 19450
# 5c1a887d9011bd0013369c13: 19451
# 5c1a87e99011bd001436a31f: 19464
# 5c1a87259011bd001436a172: 19474
# 5c1a85a09011bd00113691b3: 19488
# 5c1a84e09011bd001436978c: 19495
# 5c1a84109011bd001436961c: 19501
# 5c1a834c9011bd0015368f62: 19502
# 5c1a827b9011bd0014369312: 19503
# 5c1a819c9011bd0013368ef8: 19504
# 5c1a80e99011bd0014369012: 19507
# 5c1a7ff99011bd0014368e65: 19515
# 5c35480c1de80b00179bbfb8: 19619
# 5c3548b71de80b0024480f18: 19639
# 5c354a6a1de80b00156d3e3f: 19654
# 5c1a7f4c9011bd0013368c1d: 19658
# 5c353e781de80b0024480ea4: 19689
# 5c1a7eb09011bd0011368a7c: 19697
# 5c3512591de80b0014f69a3a: 19727
# 5c3544bd1de80b0024480ee8: 19731
# 5c3532f31de80b0014f69ada: 19738
# 5c35409f1de80b00179bbfa2: 19743
# 5c1a87bc9011bd001436a2bc: 19790
# 5c1a86f09011bd0013369950: 19800
# 5c1a867e9011bd0011369434: 19801
# 5c1a861a9011bd0014369dec: 19812
# 5c1a85639011bd0014369889: 19814
# 5c1a84719011bd00153690ae: 19815
# 5c1a84139011bd0015369036: 19817
# 5c1a839b9011bd0011368fab: 19822
# 5c1a82ca9011bd0015368ee6: 19830
# 5c1a818d9011bd0015368d8c: 80225
# 5c1a80e79011bd0013368e00: 82063
# 5c1a800c9011bd0015368c27: 82962
# 5c1a7f289011bd0011368af7: 83010
# 5c1a7e169011bd0015368993: 83835
# 5c1a86d39011bd001336991a: 85005
# 5c1a86589011bd0014369f4a: 85400
# 5c1a85a09011bd00143698f1: 86061
# 5c1a84e79011bd001436979e: 86252
# 5c1a754e9011bd0014368976: 90683
# 5c1a754e9011bd001436897a: 91460
# 5c1a754f9011bd00153688a8: 91855
# 5c1a754e9011bd00153688a4: 93204
# 5c1a754e9011bd00153688a6: 93274
# 5c1a754e9011bd001436897c: 94028
# 5c1a754e9011bd0014368978: 98718
# 5c1a754e9011bd00113688be: 99949

# %% [markdown]
# And the sessions from a project as shown below. Sessions are available as child nodes of the project container. You can access a child node by using the `.` attribute on a container. Here, we use `find_first()`.

# %%
sessions = project.sessions.find_first()
sessions
# Out:
# {'age': None,
#  'analyses': None,
#  'created': datetime.datetime(2018, 12, 19, 17, 21, 42, 780000, tzinfo=tzutc()),
#  'files': [],
#  'group': 'mcieslak',
#  'id': '5c1a7e269011bd0011368995',
#  'info': {u'BIDS': {u'Label': u'day2',
#                     u'Subject': u'17378',
#                     u'ignore': False,
#                     u'template': u'session'}},
#  'info_exists': True,
#  'label': 'day2',
#  'modified': datetime.datetime(2018, 12, 19, 17, 55, 51, 723000, tzinfo=tzutc()),
#  'notes': [],
#  'operator': 'TK',
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'mcieslak',
#              'project': '5c1a61e69011bd0011368884',
#              'session': None,
#              'subject': '5c1a7e269011bd0011368994'},
#  'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#  'project': '5c1a61e69011bd0011368884',
#  'project_has_template': None,
#  'public': None,
#  'satisfies_template': None,
#  'subject': {'age': None,
#              'analyses': None,
#              'code': '17378',
#              'cohort': None,
#              'created': datetime.datetime(2018, 12, 19, 17, 21, 42, tzinfo=tzutc()),
#              'ethnicity': None,
#              'files': None,
#              'firstname': None,
#              'id': '5c1a7e269011bd0011368994',
#              'info': {},
#              'info_exists': False,
#              'label': '17378',
#              'lastname': None,
#              'modified': datetime.datetime(2018, 12, 28, 16, 54, 0, 396000, tzinfo=tzutc()),
#              'notes': None,
#              'parents': {'acquisition': None,
#                          'analysis': None,
#                          'group': 'mcieslak',
#                          'project': '5c1a61e69011bd0011368884',
#                          'session': None,
#                          'subject': None},
#              'permissions': [{'access': 'admin',
#                               'id': 'thadbrown@flywheel.io'},
#                              {'access': 'admin',
#                               'id': 'mattcieslak@gmail.com'},
#                              {'access': 'admin',
#                               'id': 'azeez.adebimpe5@gmail.com'},
#                              {'access': 'admin',
#                               'id': 'tinashemtapera@gmail.com'},
#                              {'access': 'admin', 'id': 'adebimpe@upenn.edu'},
#                              {'access': 'admin', 'id': 'mcieslak@upenn.edu'},
#                              {'access': 'admin', 'id': 'holder@upenn.edu'}],
#              'project': '5c1a61e69011bd0011368884',
#              'public': None,
#              'race': None,
#              'sex': None,
#              'species': None,
#              'strain': None,
#              'tags': None,
#              'type': None},
#  'tags': [],
#  'timestamp': datetime.datetime(2012, 8, 26, 18, 15, 59, tzinfo=tzutc()),
#  'timezone': 'America/New_York',
#  'uid': '12840113745101000100200041142438533706583',
#  'weight': None}

# %% [markdown]
# Notice that the use of `()` on a container returns an iteratable list, but without the function parentheses, the container is an in-built attribute that indexes the flywheel database:

# %%
type(project.subjects())
# Out:
# list

# %%
type(project.subjects)
# Out:
# flywheel.finder.Finder

# %% [markdown]
# The `get()` function can be used to go directly to a container:

# %%
subject = fw.get("5c1a82ca9011bd0015368ee6")

# %% [markdown]
# And while containers are not quite Russian nesting dolls, they can still be treated as such (project > subject > session > aqsuisition)

# %%
for ses in subject.sessions():
    print('%s: %s' % (ses.id, ses.label))
# Out:
# 5c1a82ca9011bd0015368ee7: neff2

# %%
ses1 = fw.get("5c1a82ca9011bd0015368ee7")

# %%
ses1.acquisitions()
# Out:
# [{'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 628000, tzinfo=tzutc()),
#   'files': [{'classification': {},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 38, 919000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '5c728e0c-3f7e-4acf-84f2-8aed91daf589',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 252000, tzinfo=tzutc()),
#              'name': 'B0map_onesizefitsall_v4.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 1657355,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0013369088',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'B0map_onesizefitsall_v4',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 861000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 37, 45, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613360399793028791000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 396000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Structural'],
#                                 u'Measurement': [u'T1']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 16, 882000, tzinfo=tzutc()),
#              'hash': '',
#              'id': 'ffec171d-df36-4dda-ae9b-84bb9a75b065',
#              'info': {u'BIDS': {u'Filename': u'MPRAGE_TI1100_ipat2.dicom.zip',
#                                 u'Folder': u'sourcedata',
#                                 u'Path': u'sourcedata/sub-19830/ses-neff2',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'dicom_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 139000, tzinfo=tzutc()),
#              'name': 'MPRAGE_TI1100_ipat2.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 11953289,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Structural'],
#                                 u'Measurement': [u'T1']},
#              'created': datetime.datetime(2018, 12, 19, 22, 23, 49, 114000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-e1d1b6d649e307e7d5ac720656a8300b31bf6b39a45b799aee1b44fda65ec0ccce16188fddcd2c9fc1e5f56c479490ba',
#              'id': '8dfabd13-5fbc-463a-9a7f-8ceb00334183',
#              'info': {u'BIDS': {u'Acq': u'',
#                                 u'Ce': u'',
#                                 u'Filename': u'sub-19830_ses-neff2_T1w.nii.gz',
#                                 u'Folder': u'anat',
#                                 u'Mod': u'',
#                                 u'Modality': u'T1w',
#                                 u'Path': u'sub-19830/ses-neff2/anat',
#                                 u'Rec': u'',
#                                 u'Run': u'',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'anat_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 480000, tzinfo=tzutc()),
#              'name': 'MPRAGE_TI1100_ipat2_2.nii.gz',
#              'origin': {'id': '5c1a986c9011bd001336a7fa',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 7335196,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Structural'],
#                                 u'Measurement': [u'T1']},
#              'created': datetime.datetime(2018, 12, 20, 7, 35, 9, 58000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-8e5c848cb70510c6cd2d45af4319014403eea1d7f4d58f3291fe592f448085928788a424bb28c75bad9f546b052031b9',
#              'id': '88ef0632-cee7-49e8-99ab-b1097b236f4a',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'text/html',
#              'modality': None,
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 505000, tzinfo=tzutc()),
#              'name': 'MPRAGE_TI1100_ipat2_2_mriqc.qa.html',
#              'origin': {'id': '5c1ac4f59011bd001536b2f0',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 18041214,
#              'tags': [],
#              'type': 'qa',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0013369087',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'MPRAGE_TI1100_ipat2',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 676000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 31, 28, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613275264458126177000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 581000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Non-Image']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 37, 703000, tzinfo=tzutc()),
#              'hash': '',
#              'id': 'cab5acb8-8407-43ea-8937-3e65eae73adf',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'SR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 365000, tzinfo=tzutc()),
#              'name': 'PhoenixZIPReport.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 214917,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd00143693a8',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'PhoenixZIPReport',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 978000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 19, 10, 17, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '131221107524316702430000018030612472060400000110'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 351000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 12, 364000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '6a9e349a-3f92-4e91-afd8-e3782adf149f',
#              'info': {u'BIDS': {u'Filename': u'ep2d_effort1_236.dicom.zip',
#                                 u'Folder': u'sourcedata',
#                                 u'Path': u'sourcedata/sub-19830/ses-neff2',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'dicom_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 287000, tzinfo=tzutc()),
#              'name': 'ep2d_effort1_236.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 59804909,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 22, 23, 52, 669000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-70b0e772a0b91e490a439eb48663be03e5b29ec3dbd1c8624e8b69e8911b2682960d0ce06d76c4536700aeb78c9337f3',
#              'id': '9338e301-6481-4144-92ae-b1d88384ee7f',
#              'info': {u'BIDS': {u'Acq': u'',
#                                 u'Echo': u'',
#                                 u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz',
#                                 u'Folder': u'func',
#                                 u'Modality': u'sbref',
#                                 u'Path': u'sub-19830/ses-neff2/func',
#                                 u'Rec': u'',
#                                 u'Run': u'',
#                                 u'Task': u'',
#                                 u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'",
#                                 u'ignore': False,
#                                 u'template': u'func_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 13, 19, 49, 48, 836000, tzinfo=tzutc()),
#              'name': 'ep2d_effort1_236_6.nii.gz',
#              'origin': {'id': '5c1a98609011bd001436b7a0',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 50881975,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 20, 7, 32, 22, 910000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-9d39bd3216d370752c8ec959378c8f708e028f9b09bfdba50894a3fdba37e39727a4df47fa2bf8e915a5a486b5541795',
#              'id': '780f2340-3c78-4e4a-b803-fe16fe951ea1',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'text/html',
#              'modality': None,
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 601000, tzinfo=tzutc()),
#              'name': 'ep2d_effort1_236_6_mriqc.qa.html',
#              'origin': {'id': '5c1ac4f89011bd001536b2f1',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 2918155,
#              'tags': [],
#              'type': 'qa',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0011368ecf',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'ep2d_effort1_236',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 901000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 41, 29, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613380027650529234000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 486000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 35, 342000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '9eceeb49-0d20-4741-9780-b72c80656b24',
#              'info': {u'BIDS': {u'Filename': u'ep2d_effort2_236.dicom.zip',
#                                 u'Folder': u'sourcedata',
#                                 u'Path': u'sourcedata/sub-19830/ses-neff2',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'dicom_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 314000, tzinfo=tzutc()),
#              'name': 'ep2d_effort2_236.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 59917312,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 22, 27, 16, 828000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-31738c8273aeacdc13b8746266b7c9f715a3c951a26cc5d4bdc533d21c015b40193d01ea7233e5a6bd0a41a4d68c8b0c',
#              'id': '909db5e0-2d34-45ac-8ce6-ba4c4a93209d',
#              'info': {u'BIDS': {u'Acq': u'',
#                                 u'Echo': u'',
#                                 u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz',
#                                 u'Folder': u'func',
#                                 u'Modality': u'sbref',
#                                 u'Path': u'sub-19830/ses-neff2/func',
#                                 u'Rec': u'',
#                                 u'Run': u'',
#                                 u'Task': u'',
#                                 u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'",
#                                 u'ignore': False,
#                                 u'template': u'func_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 13, 19, 49, 48, 865000, tzinfo=tzutc()),
#              'name': 'ep2d_effort2_236_7.nii.gz',
#              'origin': {'id': '5c1a98cb9011bd001436b810',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 50995788,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 20, 8, 18, 54, 299000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-ac423acb0cebb6ff8b84c96ca3bd9a27e6c63a0bf8a8d96b89e95b29028cf49d209671421cccca8de96d4093f6ea01a6',
#              'id': '9c1c8fe0-d3c4-4fbb-ba5d-d77d10ae55d2',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'text/html',
#              'modality': None,
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 658000, tzinfo=tzutc()),
#              'name': 'ep2d_effort2_236_7_mriqc.qa.html',
#              'origin': {'id': '5c1ac5c49011bd001436dae6',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 2945175,
#              'tags': [],
#              'type': 'qa',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0011368ed0',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'ep2d_effort2_236',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 939000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 54, 27, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613531583854161570000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 307000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 17, 42, 59, 647000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '846a2ea7-bddd-414b-b149-9cfc1ac9277e',
#              'info': {u'BIDS': {u'Filename': u'ep2d_effort3_1416.dicom.zip',
#                                 u'Folder': u'sourcedata',
#                                 u'Path': u'sourcedata/sub-19830/ses-neff2',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'dicom_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 393000, tzinfo=tzutc()),
#              'name': 'ep2d_effort3_1416.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 420949340,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 22, 24, 53, 712000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-e7921318266a2eeb8b421d73a43a34ae1de1de5bfb270ec1eceb3874da3ff38340e94226d41fe86ae79d354798399ef3',
#              'id': 'bf0d97e9-8bbc-4754-9efc-159ed2c4b8b1',
#              'info': {u'BIDS': {u'Acq': u'',
#                                 u'Echo': u'',
#                                 u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_bold.nii.gz',
#                                 u'Folder': u'func',
#                                 u'Modality': u'bold',
#                                 u'Path': u'sub-19830/ses-neff2/func',
#                                 u'Rec': u'',
#                                 u'Run': u'',
#                                 u'Task': u'',
#                                 u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'",
#                                 u'ignore': False,
#                                 u'template': u'func_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 13, 19, 49, 48, 901000, tzinfo=tzutc()),
#              'name': 'ep2d_effort3_1416_8.nii.gz',
#              'origin': {'id': '5c1a983f9011bd001336a7e4',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 368468316,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 20, 8, 14, 46, 507000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-f6c36e2ac73dd4307b2c8a1e84a40487ab305ba2d9be10a83e7872481e33838b358eec6d28728a3e9d96d359d9e57142',
#              'id': '746e9f35-05d8-4217-99ad-7b7efb90e95b',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'text/html',
#              'modality': None,
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 714000, tzinfo=tzutc()),
#              'name': 'ep2d_effort3_1416_8_mriqc.qa.html',
#              'origin': {'id': '5c1ac5359011bd001536b305',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 3905343,
#              'tags': [],
#              'type': 'qa',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0013369086',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'ep2d_effort3_1416',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 55, 28000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 19, 10, 27, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030614061775472093907000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 725000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 39, 213000, tzinfo=tzutc()),
#              'hash': '',
#              'id': 'c5acf558-6c59-4018-9b78-7b4b2434eded',
#              'info': {u'BIDS': {u'Filename': u'ep2d_single.dicom.zip',
#                                 u'Folder': u'sourcedata',
#                                 u'Path': u'sourcedata/sub-19830/ses-neff2',
#                                 u'error_message': u'',
#                                 u'ignore': False,
#                                 u'template': u'dicom_file',
#                                 u'valid': True}},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 191000, tzinfo=tzutc()),
#              'name': 'ep2d_single.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 262350,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Functional'],
#                                 u'Measurement': [u'T2*']},
#              'created': datetime.datetime(2018, 12, 19, 22, 24, 4, 956000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-316ef768fb6b275ae7a20566fbd7f129b2f0b8ffcd16e3c821d39aeecbcb07c97b65acbd031eb62a6131ae1757fd1206',
#              'id': '2f79839b-5855-4e33-99c2-b595e4aee7f3',
#              'info': {u'BIDS': {u'Acq': u'',
#                                 u'Echo': u'',
#                                 u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz',
#                                 u'Folder': u'func',
#                                 u'Modality': u'sbref',
#                                 u'Path': u'sub-19830/ses-neff2/func',
#                                 u'Rec': u'',
#                                 u'Run': u'',
#                                 u'Task': u'',
#                                 u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'",
#                                 u'ignore': False,
#                                 u'template': u'func_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 13, 19, 49, 48, 807000, tzinfo=tzutc()),
#              'name': 'ep2d_single_3.nii.gz',
#              'origin': {'id': '5c1a98ef9011bd0011369e1f',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 223433,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd00143693a9',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'ep2d_single',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 783000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 34, 58, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613345531041627741000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 537000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Custom': [],
#                                 u'Intent': [u'Fieldmap'],
#                                 u'Measurement': [u'B0']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 36, 832000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '39b3bce9-dec6-4dfa-b246-8d4b5db67436',
#              'info': {},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 14, 21, 38, 26, 320000, tzinfo=tzutc()),
#              'name': 'B0map_onesizefitsall_v4.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 2946086,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Custom': [],
#                                 u'Intent': [u'Fieldmap'],
#                                 u'Measurement': [u'B0']},
#              'created': datetime.datetime(2019, 2, 14, 21, 38, 30, 973000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-d9861ca470a6876324203749f70f602fee846b68fc815ae49889b5ad2590ea5d4dc774c52cbab1b4fee153669b58503b',
#              'id': '501a073a-2474-4e4e-bee3-57979964f227',
#              'info': {},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 14, 21, 38, 30, 169000, tzinfo=tzutc()),
#              'name': 'B0map_onesizefitsall_v4_4_e2.nii.gz',
#              'origin': {'id': '5c65dfd2ba258000273891b9',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 157859,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Custom': [],
#                                 u'Intent': [u'Fieldmap'],
#                                 u'Measurement': [u'B0']},
#              'created': datetime.datetime(2019, 2, 14, 21, 38, 31, 502000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-d7b7f40c0d00402d64f551f313c45f42cb47dcb532886b03e0f8ad09930380909ee59b720b147fb5be82c9195eca2974',
#              'id': '7be7e95c-a9b0-45be-9529-b3d8358f53cf',
#              'info': {},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2019, 2, 14, 21, 38, 30, 169000, tzinfo=tzutc()),
#              'name': 'B0map_onesizefitsall_v4_4_e1.nii.gz',
#              'origin': {'id': '5c65dfd2ba258000273891b9',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 169997,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0011368ed1',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'foo2',
#   'modified': datetime.datetime(2019, 2, 14, 21, 40, 19, 914000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 37, 43, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613360399791728790000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 673000, tzinfo=tzutc()),
#   'files': [{'classification': {u'Intent': [u'Localizer'],
#                                 u'Measurement': [u'T2']},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 39, 46000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '90f954b7-8e2b-4268-ae00-352fff512137',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 101000, tzinfo=tzutc()),
#              'name': 'localizer.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 179609,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Localizer'],
#                                 u'Measurement': [u'T2']},
#              'created': datetime.datetime(2018, 12, 19, 22, 24, 5, 114000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-d1ecd6920e49a291a379d2a0a6534bceafea9b8309509ceabcea73a69a203d1fb2181f72b6815a1d1a11566d09192689',
#              'id': '14f49373-e419-4ded-95f7-288632c88140',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 391000, tzinfo=tzutc()),
#              'name': 'localizer_1_i00003.nii.gz',
#              'origin': {'id': '5c1a98eb9011bd001436b830',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 23829,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Localizer'],
#                                 u'Measurement': [u'T2']},
#              'created': datetime.datetime(2018, 12, 19, 22, 24, 5, 481000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-1c1b3499a6fc9602010634997b81482f90cdc2bf85514212024503defffc08c6e9f521359e03b998f39e23ed695e7595',
#              'id': '59fad3e6-2a43-401c-bcb7-d38a7c8faa2d',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 414000, tzinfo=tzutc()),
#              'name': 'localizer_1_i00002.nii.gz',
#              'origin': {'id': '5c1a98eb9011bd001436b830',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 25234,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None},
#             {'classification': {u'Intent': [u'Localizer'],
#                                 u'Measurement': [u'T2']},
#              'created': datetime.datetime(2018, 12, 19, 22, 24, 5, 883000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-efceff3f2b04da27067d42e9cab83c7ccb14994c036099e46ef19b8e08da853304081f8f1b909302343b5d0da997f2f2',
#              'id': 'ffcf7d55-05e1-4273-aeaa-3a9d4fa677ca',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/octet-stream',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 20, 17, 15, 21, 455000, tzinfo=tzutc()),
#              'name': 'localizer_1_i00001.nii.gz',
#              'origin': {'id': '5c1a98eb9011bd001436b830',
#                         'method': None,
#                         'name': None,
#                         'type': 'job',
#                         'via': None},
#              'replaced': None,
#              'size': 27538,
#              'tags': [],
#              'type': 'nifti',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd0013369089',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'localizer',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 636000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 27, 12, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '13122110752431670242018030613270568381825858000'}, {'analyses': None,
#   'collections': None,
#   'created': datetime.datetime(2018, 12, 19, 17, 41, 30, 440000, tzinfo=tzutc()),
#   'files': [{'classification': {},
#              'created': datetime.datetime(2018, 12, 19, 17, 43, 21, 104000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '44b0daaf-755e-4636-ab29-d6705554f807',
#              'info': {u'BIDS': u'NA'},
#              'info_exists': True,
#              'mimetype': 'application/zip',
#              'modality': 'MR',
#              'modified': datetime.datetime(2018, 12, 19, 21, 57, 49, 168000, tzinfo=tzutc()),
#              'name': 'sag mpr.dicom.zip',
#              'origin': {'id': 'mattcieslak@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 6950815,
#              'tags': [],
#              'type': 'dicom',
#              'zip_member_count': None}],
#   'id': '5c1a82ca9011bd00143693a7',
#   'info': {u'BIDS': {u'ignore': False, u'template': u'acquisition'}},
#   'info_exists': True,
#   'label': 'sag mpr',
#   'modified': datetime.datetime(2018, 12, 19, 17, 56, 54, 717000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': '5c1a61e69011bd0011368884',
#               'session': '5c1a82ca9011bd0015368ee7',
#               'subject': '5c1a82ca9011bd0015368ee6'},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'session': '5c1a82ca9011bd0015368ee7',
#   'tags': [],
#   'timestamp': datetime.datetime(2018, 3, 6, 18, 32, 42, tzinfo=tzutc()),
#   'timezone': 'America/New_York',
#   'uid': '131221107524316702430000018030618195294800000299'}]

# %% [markdown]
# File are accessed via the `files` key, but it's easier to use `get()` on the BSON id.

# %%
f1 = fw.get("5c1a82ca9011bd0011368ed1")

# %%
f1.label
# Out:
# 'foo'

# %% [markdown]
# ## Viewing the data as Tabular
#
# Using `View()`, you can create a tabular index of the data you want to search through. From there, use `pandas` to read it in as a dataframe:

# %%
import pandas as pd

view = fw.View(columns='subject')
df = fw.read_view_dataframe(view,project.id)
df
# Out:
#                    project.id project.label  subject.cohort  \
# 0    5c1a61e69011bd0011368884    Reward2018             NaN
# 1    5c1a61e69011bd0011368884    Reward2018             NaN
# 2    5c1a61e69011bd0011368884    Reward2018             NaN
# 3    5c1a61e69011bd0011368884    Reward2018             NaN
# 4    5c1a61e69011bd0011368884    Reward2018             NaN
# 5    5c1a61e69011bd0011368884    Reward2018             NaN
# 6    5c1a61e69011bd0011368884    Reward2018             NaN
# 7    5c1a61e69011bd0011368884    Reward2018             NaN
# 8    5c1a61e69011bd0011368884    Reward2018             NaN
# 9    5c1a61e69011bd0011368884    Reward2018             NaN
# 10   5c1a61e69011bd0011368884    Reward2018             NaN
# 11   5c1a61e69011bd0011368884    Reward2018             NaN
# 12   5c1a61e69011bd0011368884    Reward2018             NaN
# 13   5c1a61e69011bd0011368884    Reward2018             NaN
# 14   5c1a61e69011bd0011368884    Reward2018             NaN
# 15   5c1a61e69011bd0011368884    Reward2018             NaN
# 16   5c1a61e69011bd0011368884    Reward2018             NaN
# 17   5c1a61e69011bd0011368884    Reward2018             NaN
# 18   5c1a61e69011bd0011368884    Reward2018             NaN
# 19   5c1a61e69011bd0011368884    Reward2018             NaN
# 20   5c1a61e69011bd0011368884    Reward2018             NaN
# 21   5c1a61e69011bd0011368884    Reward2018             NaN
# 22   5c1a61e69011bd0011368884    Reward2018             NaN
# 23   5c1a61e69011bd0011368884    Reward2018             NaN
# 24   5c1a61e69011bd0011368884    Reward2018             NaN
# 25   5c1a61e69011bd0011368884    Reward2018             NaN
# 26   5c1a61e69011bd0011368884    Reward2018             NaN
# 27   5c1a61e69011bd0011368884    Reward2018             NaN
# 28   5c1a61e69011bd0011368884    Reward2018             NaN
# 29   5c1a61e69011bd0011368884    Reward2018             NaN
# ..                        ...           ...             ...
# 327  5c1a61e69011bd0011368884    Reward2018             NaN
# 328  5c1a61e69011bd0011368884    Reward2018             NaN
# 329  5c1a61e69011bd0011368884    Reward2018             NaN
# 330  5c1a61e69011bd0011368884    Reward2018             NaN
# 331  5c1a61e69011bd0011368884    Reward2018             NaN
# 332  5c1a61e69011bd0011368884    Reward2018             NaN
# 333  5c1a61e69011bd0011368884    Reward2018             NaN
# 334  5c1a61e69011bd0011368884    Reward2018             NaN
# 335  5c1a61e69011bd0011368884    Reward2018             NaN
# 336  5c1a61e69011bd0011368884    Reward2018             NaN
# 337  5c1a61e69011bd0011368884    Reward2018             NaN
# 338  5c1a61e69011bd0011368884    Reward2018             NaN
# 339  5c1a61e69011bd0011368884    Reward2018             NaN
# 340  5c1a61e69011bd0011368884    Reward2018             NaN
# 341  5c1a61e69011bd0011368884    Reward2018             NaN
# 342  5c1a61e69011bd0011368884    Reward2018             NaN
# 343  5c1a61e69011bd0011368884    Reward2018             NaN
# 348          19689               NaN           NaN        None
# 349          19743               NaN           NaN        None
# 350         105168               NaN           NaN        None
# 351         105490               NaN           NaN        None
# 352          19731               NaN           NaN        None
# 353         109741               NaN           NaN        None
# 354          19619               NaN           NaN        None
# 355          19639               NaN           NaN        None
# 356          19654               NaN           NaN        None
#
#     subject.species subject.strain subject.type
# 0              None           None         None
# 1              None           None         None
# 2              None           None         None
# 3              None           None         None
# 4              None           None         None
# 5              None           None         None
# 6              None           None         None
# 7              None           None         None
# 8              None           None         None
# 9              None           None         None
# 10             None           None         None
# 11             None           None         None
# 12             None           None         None
# 13             None           None         None
# 14             None           None         None
# 15             None           None         None
# 16             None           None         None
# 17             None           None         None
# 18             None           None         None
# 19             None           None         None
# 20             None           None         None
# 21             None           None         None
# 22             None           None         None
# 23             None           None         None
# 24             None           None         None
# 25             None           None         None
# 26             None           None         None
# 27             None           None         None
# 28             None           None         None
# 29             None           None         None
# ..              ...            ...          ...
# 327            None           None         None
# 328            None           None         None
# 329            None           None         None
# 330            None           None         None
# 331            None           None         None
# 332            None           None         None
# 333            None           None         None
# 334            None           None         None
# 335            None           None         None
# 336            None           None         None
# 337            None           None         None
# 338            None           None         None
# 339            None           None         None
# 340            None           None         None
# 341            None           None         None
# 342            None           None         None
# 343            None           None         None
# 344            None           None         None
# 345            None           None         None
# 346            None           None         None
# 347            None           None         None
# 348            None           None         None
# 349            None           None         None
# 350            None           None         None
# 351            None           None         None
# 352            None           None         None
# 353            None           None         None
# 354            None           None         None
# 355            None           None         None
# 356            None           None         None
#
# [357 rows x 13 columns]

# %% [markdown]
# In this implementation, there is a clear hierarchy to be followed. Basically, you specify the columns of the minor container you want to return, as members of some major container you have already assigned in the environment. So for example, if I wanted to see the name and size of all of the files of a session from a participant:

# %%
f1.id
# Out:
# '5c1a82ca9011bd0011368ed1'

# %%
view = fw.View(columns='file')
df = fw.read_view_dataframe(view,f1.id)
df

# %%
fw.print_view_columns()
# Out:
# project (group): All column aliases belonging to project
# project.id (string): The project id
# project.label (string): The project label
# project.info (object): The freeform project metadata
# subject (group): All column aliases belonging to subject
# subject.id (string): The subject id
# subject.label (string): The subject label or code
# subject.firstname (string): The subject first name
# subject.lastname (string): The subject last name
# subject.sex (string): The subject sex (one of female|male|other|unknown)
# subject.race (string): The subject race (one of American Indian or Alaska Native|Asian|Native Hawaiian or Other Pacific Islander|Black or African American|White|More Than One Race|Unknown or Not Reported)
# subject.ethnicity (string): The subject ethnicity (one of Not Hispanic or Latino|Hispanic or Latino|Unknown or Not Reported)
# subject.cohort (string): The subject cohort (one of Control|Study|Training|Test|Validation)
# subject.type (string): The subject type (one of human|animal|phantom)
# subject.species (string): The subject species
# subject.strain (string): The subject strain
# subject.info (object): The freeform subject metadata
# session (group): All column aliases belonging to session
# session.id (string): The session id
# session.label (string): The session label
# session.operator (string): The session operator name
# session.timestamp (string): The session timestamp
# session.timezone (string): The session timezone
# session.info (object): The freeform session metadata
# session.age (int): The subject age at time of session, in seconds
# session.age_years (float): The subject age at time of session, in years
# session.age_months (float): The subject age at time of session, in months
# session.age_weeks (float): The subject age at time of session, in weeks
# session.age_days (float): The subject age at time of session, in days
# session.weight (float): The subject weight at time of session, in kg
# acquisition (group): All column aliases belonging to acquisition
# acquisition.id (string): The acquisition id
# acquisition.label (string): The acquisition label
# acquisition.timestamp (string): The acquisition timestamp
# acquisition.timezone (string): The acquisition timezone
# acquisition.info (object): The freeform acquisition metadata
# analysis (group): All column aliases belonging to analysis
# analysis.id (string): The analysis id
# analysis.label (string): The analysis label
# analysis.info (object): The freeform analysis metadata
# file (group): All column aliases belonging to file
# file.id (string): The file id
# file.name (string): The filename
# file.type (string): The type of file (e.g., dicom, image, document)
# file.mimetype (string): The file mime type (e.g. application/json, text/csv)
# file.modality (string): The file instrument type (e.g., MR, CT)
# file.classification (string): The file classification object
# file.size (int): The size of the file, in bytes
# file.row_number (int): The 0-indexed row number from file
# file.info (object): The freeform file metadata

# %%
view = fw.View(columns='session')
df = fw.read_view_dataframe(view, ses.id)
df
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-91-eafcfcdcb4eb> in <module>()
#       1 view = fw.View(columns='session')
# ----> 2 df = fw.read_view_dataframe(view, ses.id)
#       3 df
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/client.pyc in read_view_dataframe(self, view, container_id, opts, **kwargs)
#     228         :return: A pandas DataFrame
#     229         """
# --> 230         return self._fw.read_view_dataframe(view, container_id, opts=opts, **kwargs)
#     231
#     232
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/flywheel.pyc in read_view_dataframe(self, view, container_id, opts, **kwargs)
#    6142
#    6143         kwargs['format'] = 'json-flat'
# -> 6144         resp = self.read_view_data(view, container_id, decode=False, **kwargs)
#    6145         if resp:
#    6146             try:
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/flywheel.pyc in read_view_data(self, view, container_id, decode, **kwargs)
#    6118             resp = self.views_api.evaluate_view_with_http_info(view, container_id, **kwargs)
#    6119         else:
# -> 6120             resp = self.views_api.evaluate_view_adhoc_with_http_info(container_id, view, **kwargs)
#    6121         resp.raw.decode_content = True
#    6122         if decode:
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/api/views_api.pyc in evaluate_view_adhoc_with_http_info(self, container_id, body, **kwargs)
#     453             _request_timeout=params.get('_request_timeout'),
#     454             _request_out=params.get('_request_out'),
# --> 455             collection_formats=collection_formats)
#     456
#     457     def get_view(self, view_id, **kwargs):  # noqa: E501
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/api_client.pyc in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     348                                    response_type, auth_settings,
#     349                                    _return_http_data_only, collection_formats,
# --> 350                                    _preload_content, _request_timeout, _request_out)
#     351         else:
#     352             thread = self.pool.apply_async(self.__call_api, (resource_path,
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/api_client.pyc in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _request_out)
#     178             post_params=post_params, body=body,
#     179             _preload_content=_preload_content,
# --> 180             _request_timeout=_request_timeout)
#     181
#     182         self.last_response = response_data
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/api_client.pyc in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     391                                          _preload_content=_preload_content,
#     392                                          _request_timeout=_request_timeout,
# --> 393                                          body=body)
#     394         elif method == "PUT":
#     395             return self.rest_client.PUT(url,
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/rest.pyc in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     218                             _preload_content=_preload_content,
#     219                             _request_timeout=_request_timeout,
# --> 220                             body=body)
#     221
#     222     def PUT(self, url, headers=None, query_params=None, post_params=None,
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/rest.pyc in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     121                     stream=stream,
#     122                     timeout=_request_timeout,
# --> 123                     headers=headers)
#     124             elif headers['Content-Type'] == 'application/x-www-form-urlencoded':  # noqa: E501
#     125                 r = self.session.request(method, url,
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     613
#     614         # Response manipulation hooks
# --> 615         r = dispatch_hook('response', hooks, r, **kwargs)
#     616
#     617         # Persist cookies
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/requests/hooks.pyc in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29             hooks = [hooks]
#      30         for hook in hooks:
# ---> 31             _hook_data = hook(hook_data, **kwargs)
#      32             if _hook_data is not None:
#      33                 hook_data = _hook_data
#
# /data/joy/BBL/applications/miniconda3/envs/py2k/lib/python2.7/site-packages/flywheel/rest.pyc in response_hook(self, resp, *args, **kwargs)
#      71     def response_hook(self, resp, *args, **kwargs):
#      72         if not 200 <= resp.status_code <= 299 and resp.status_code != 302:
# ---> 73             raise ApiException(http_resp=resp)
#      74
#      75     def request(self, method, url, query_params=None, headers=None,
#
# ApiException: (500) Reason: Internal Server Error

# %% [markdown]
# ## Manipulating Data Values
#
# We can manipulate field values by passing a key-value pair to the `update()` function. Then, to update the object in the python environment, simply reassign it with `reload()`:

# %%
newname = {"label":"foo1"}
f1.update(newname)
f1 = f1.reload()

# %%
f1.label
# Out:
# 'foo1'
